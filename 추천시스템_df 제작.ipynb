# %%
import pandas as pd
import numpy as np
import warnings; warnings.filterwarnings('ignore')

movies = pd.read_csv('tmdb_5000_movies.csv')
print(movies.shape)
movies.head(1)
# Out:
# (4803, 20)
#       budget  ... vote_count
# 0  237000000  ...      11800
#
# [1 rows x 20 columns]

# %%
movies.iloc[0, 4]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies.describe
# Out:
# <bound method NDFrame.describe of          budget  ... vote_count
# 0     237000000  ...      11800
# 1     300000000  ...       4500
# 2     245000000  ...       4466
# 3     250000000  ...       9106
# 4     260000000  ...       2124
# ...         ...  ...        ...
# 4798     220000  ...        238
# 4799       9000  ...          5
# 4800          0  ...          6
# 4801          0  ...          7
# 4802          0  ...         16
#
# [4803 rows x 20 columns]>

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
eulji = pd.read_csv('output_eulji.csv')
print(eulji.shape)
# Out:
# (2351, 9)

# %%
eulji
# Out:
#       index                                              insta  ... np  lalo
# 0         0  #을지로 #대련집 칼국수 보쌈 둘다 맛있었다 🥳 칼국수는 약간 짭짤한 소고기국시 스...  ...  1   NaN
# 1         1  20200703 종각 대련집신선한 알배추에 기름좔좔 수육 올리고시원한 무생채와 김치...  ...  1   NaN
# 2         2  20/05/26/화#저녁밥#술스타그램#종로구#관ᄉ...  ...  0   NaN
# 3         3  20/07/10/금#점심밥#혼밥#종로구#관수동...  ...  0   NaN
# 4         4  #대련집 🐷야들야들한 #보쌈 도 맛있고묘하게 스프맛이 나던 #칼국수 도 좋네 🤭정신...  ...  1   NaN
# ...     ...                                                ...  ... ..   ...
# 2346     58  수업 듣다 졸려서 그냥 학원에서 운영하는 카페에서 사 마셨는뎈ㅋㅋㅋㅋ 기대 안 했는...  ...  0   NaN
# 2347     59             #파고다강남 #카페허 #cafehuh 이곳이 바로 혜자카페인가 huh  ...  0   NaN
# 2348     60  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  1   NaN
# 2349     61  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  1   NaN
# 2350     62  #파고다 #C004 #파고다캘리 #파고다그램 #캘리그라피프로젝트#힘을내요슈퍼파월 #...  ...  0   NaN
#
# [2351 rows x 9 columns]

# %%
eulji.dtypes
# Out:
# index          int64
# insta         object
# date          object
# like         float64
# loca          object
# has           object
# sentiment    float64
# np             int64
# lalo         float64
# dtype: object

# %%
eulji.isnull().sum()
# Out:
# index           0
# insta           0
# date            0
# like            6
# loca         1083
# has             0
# sentiment       0
# np              0
# lalo         2351
# dtype: int64

# %%
eulji = eulji.drop('lalo', axis=1)

# %%
eulji = eulji.dropna(axis=0)
eulji.isnull().sum()
# Out:
# index        0
# insta        0
# date         0
# like         0
# loca         0
# has          0
# sentiment    0
# np           0
# dtype: int64

# %%
eulji
# Out:
#       index                                              insta  ... sentiment  np
# 0         0  #을지로 #대련집 칼국수 보쌈 둘다 맛있었다 🥳 칼국수는 약간 짭짤한 소고기국시 스...  ...  0.960387   1
# 1         1  20200703 종각 대련집신선한 알배추에 기름좔좔 수육 올리고시원한 무생채와 김치...  ...  0.579494   1
# 2         2  20/05/26/화#저녁밥#술스타그램#종로구#관ᄉ...  ...  0.074801   0
# 3         3  20/07/10/금#점심밥#혼밥#종로구#관수동...  ...  0.413679   0
# 4         4  #대련집 🐷야들야들한 #보쌈 도 맛있고묘하게 스프맛이 나던 #칼국수 도 좋네 🤭정신...  ...  0.865343   1
# ...     ...                                                ...  ...       ...  ..
# 2328     40  Good morning💋.#카페허 #huh #EnglishCafe #영어카페 #커피...  ...  0.011229   0
# 2329     41  #강남 #파고다 에 #카페 가 있는거 아시나요? #파고다강남 11층 #카페허 에는 ...  ...  0.341825   0
# 2338     50  #카페허 #파고다 #cafehuh 잠깐휴식 그리고 다시 빡세게돌아다니기!!!!!강남...  ...  0.988808   1
# 2340     52  #종로파고다 #내일라운지 #내일 #종로핫플레이스 #카페허 누구에게나 내 일이 존재하...  ...  0.779697   1
# ...

# %%
# for i in range(18):
#     idx = eulji[eulji['loca'] == None].index
#     eulji['loca'] = eulji.drop(idx)

# eulji

# %%
# df5 = pd.DataFrame()
# df5

# %%
eulji.isnull().sum()
# Out:
# index        0
# insta        0
# date         0
# like         0
# loca         0
# has          0
# sentiment    0
# np           0
# dtype: int64

# %%
eulji['loca'].head(200)
# Out:
# 0            대련집
# 1            대련집
# 2            대련집
# 3            대련집
# 4            대련집
#          ...
# 309    동대문 그 어딘가
# 310       복국집 뽁찌
# 312       복국집 뽁찌
# 313       복국집 뽁찌
# 314        옐로우피자
# Name: loca, Length: 200, dtype: object

# %% [markdown]
# ## **빈 데이터프레임 만들기**

# %%
# from pandas import DataFrame as df
df = pd.DataFrame(index=range(0,18), columns=['name', 'senti', 'num_post', 'keyword', '업종', 'has', 'like', 'people'])
list1 = ['대련집',
                    '세운전자상가'
                    ,'시그니처타워'
                    ,'이멜다분식'
                    ,'노상공영주차장'
                    ,'복국집 뽁찌'
                    ,'호랑이커피'
                    ,'만선호프'
                    ,'동원참치인사점'
                    ,'두꺼비생태공원'
                    ,'이춘복참치종각'
                    ,'한돌참치'
                    ,'이노참치'
                    ,'종로참치'
                    ,'대도참치'
                    ,'치킨더비종로청계점'
                    ,'강남파고다어학원'
                    ,'종로파고다어학원']
for i in range(18):
    df['name'][i] = list1[i]

# k=0
# for i in range(18):
#   for j in range(18):
#       if str(eulji['loca'][j]) == str(list1[i]):
#           df['senti'][i] += eulji['sentiment'][j] / k
#           k += 1
#           break
      # else:
      #     beak:

# for i in range(18):
#     k = eulji[eulji['loca'] == list1[i]]
#     kk = k['senti'].mean()
#     print(kk)
   
df = df.drop('has', axis=1)
df = df.drop('people', axis=1)

# %%
# for i in range(1267):
#     eulji.iloc[i,5] = eulji.iloc[i,5][1:-1]
    



eulji['has']

ppppp=0
for i in eulji['has']:
    iii = i[1:-1].split(',')
    a = []
    ppppp =+ 1
    for t in iii:
        ii = t.replace('#', '')
        a.append(ii)
    # print(a)
    eulji.iloc[ppppp,5] = a

eulji['has']
    # ii = iii.replace()
    # ii = 
# for i in eulji['has'].iloc[1:-1].split(','):
#     i = i[1:-1].replace("#", "")
#     print(i)
# h = eulji.iloc[0,5]
# print(h)
# type(h)
# print(len(h))
# print(h[1:26])

# h = h[1:26]
# print(h)
# # listt = []
# # type(listt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4fd3f32de387> in <module>()
#      16         a.append(ii)
#      17     # print(a)
# ---> 18     eulji.iloc[ppppp,5] = a
#      19
#      20 eulji['has']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1017                     if len(labels) != len(value):
#    1018                         raise ValueError(
# -> 1019                             "Must have equal len keys and value "
# ...

# %%
# for i in range(18):
# y = eulji.loc[0:18, 'has']

# a = eulji[eulji['loca'] == list1[i]]
#     aa = k['loca'].count()

# %%
# eulji['like'].dtypes

# eulji.loc[0:18]

# for i in range(18)
#   yy = eulji[eulji[]]
#  y = eulji.loc[0:18, 'has']
#  df.iloc[i, 3] = y[i]
eulji.iloc[0,5] + eulji.iloc[1,5]
# Out:
# "'#을지로', '#대련집', '#우니_을지로''#재영로드', '#중구재영', '#중구맛집', '#종각역재영', '#종각역맛집', '#대련집재영', '#대련집', '#칼국수재영', '#칼국수맛집', '#종각맛집', '#을지로재영', '#을지로맛집', '#수육재영', '#수육맛집', '#종로재영', '#wine', '#酒', '#日本酒', '#맛스타그램', '#먹스타그램', '#술스타그램', '#foodporn', '#instafood', '#foodie', '#food', '#foodstagram', '#와인', '#ワイン'"

# %%
# eulji['like'] = pd.to_numeric(eulji['like'])


# eulji.dtypes
for i in range(18):
    y = eulji[eulji['loca'] == list1[i]]
    yy = y['has']
    print(yy)
    # df.iloc[i, 3] = yy[i]

# %%
list2 = [['음식점', '한식', '백반'],
        ['상가', '공간', '전자제품'],
         ['상가', '공간', '상품'],
         ['음식점', '한식', '분식'],
         ['주차장', '공간'],
         ['음식점', '일식', '복국'],
         ['음식점', '카페', '커피'],
         ['음식점', '술집', '치킨', '맥주'],
         ['음식점', '일식', '참치', '인사동'],
         ['공원', '공간', '사진'],
         ['음식점', '술집', '일식', '참치', '종각'],
         ['음식점', '술집', '일식', '참치'],
         ['음식점', '술집', '일식', '참치'],
         ['음식점', '술집', '일식', '참치', '종로'],
         ['음식점', '술집', '일식', '참치'],
         ['음식점', '술집,' '치킨', '맥주', '청계'],
         ['학원', '공간', '영어', '파고다', '강남'],
         ['학원', '공간', '영어', '파고다', '종로']]

for i in range(18):
  ######senti#####
    k = eulji[eulji['loca'] == list1[i]]
    kk = k['sentiment'].mean()
    df.iloc[i, 1] = kk
    
  #####num_post#####
    a = eulji[eulji['loca'] == list1[i]]
    aa = k['loca'].count()
    df.iloc[i, 2] = aa

  # # #####keword#####
  #   y = eulji[eulji['loca'] == list1[i]]
  #   yy = y['has']
  #   df.iloc[i, 3] = yy[i]

  # #####업종#####
    df.iloc[i, 4] = list2[i]

  # ######has####

  # ######like#####
    p = eulji[eulji['loca'] == list1[i]]
    pp = p['like'].mean()
    df.iloc[i, 5] = pp

  #####people

  
# df['senti'] = df['senti'].dropna(axis=0)
df
# Out:
#          name      senti num_post keyword                     업종     like
# 0         대련집   0.597104      147     NaN          [음식점, 한식, 백반]  184.517
# 1      세운전자상가   0.400369        8     NaN         [상가, 공간, 전자제품]   31.875
# 2      시그니처타워  0.0626069        1     NaN           [상가, 공간, 상품]       24
# 3       이멜다분식   0.565453      311     NaN          [음식점, 한식, 분식]  44.6881
# 4     노상공영주차장        NaN        0     NaN              [주차장, 공간]      NaN
# 5      복국집 뽁찌     0.6721        5     NaN          [음식점, 일식, 복국]     50.4
# 6       호랑이커피   0.464941       26     NaN          [음식점, 카페, 커피]  87.9615
# 7        만선호프   0.244496        1     NaN      [음식점, 술집, 치킨, 맥주]       16
# 8     동원참치인사점        NaN        0     NaN     [음식점, 일식, 참치, 인사동]      NaN
# 9     두꺼비생태공원        NaN        0     NaN           [공원, 공간, 사진]      NaN
# 10    이춘복참치종각        NaN        0     NaN  [음식점, 술집, 일식, 참치, 종각]      NaN
# 11       한돌참치        NaN        0     NaN      [음식점, 술집, 일식, 참치]      NaN
# ...

# %%
# k = eulji[eulji['loca'] == '대련집']
# kk = k['sentiment'].mean()
# df.iloc[0, 1] = kk

# %%
from pandas import Series, DataFrame

df2 = DataFrame({"c1":[1,2,3], "c2":[11,22,33], "c3":[111,222,333]}, index=["i1","i2","i3"])


df2
# Out:
#     c1  c2   c3
# i1   1  11  111
# i2   2  22  222
# i3   3  33  333

# %%
df2 =  df2.drop("i2", axis = 0)


df2
# Out:
#     c1  c2   c3
# i1   1  11  111
# i3   3  33  333
