# %%
import pandas as pd
import numpy as np
# from matplotlib as plt
import seaborn as sns
# %matplotib inline

data1 = pd.read_csv('insta_data_eulji.csv')

# %%
data1.describe()
# Out:
#         Unnamed: 0    sentiment
# count  2351.000000  2351.000000
# mean    435.022969     0.758283
# std     324.523069     0.330714
# min       0.000000     0.001770
# 25%     154.000000     0.615831
# 50%     381.000000     0.949241
# 75%     675.000000     0.990665
# max    1169.000000     0.998366

# %%
data1.head(10)
# Out:
#    Unnamed: 0  ... sentiment
# 0           0  ...  0.997493
# 1           1  ...  0.969207
# 2           2  ...  0.198648
# 3           3  ...  0.953208
# 4           4  ...  0.991202
# 5           5  ...  0.997139
# 6           6  ...  0.981170
# 7           7  ...  0.997879
# 8           8  ...  0.997494
# 9           9  ...  0.996662
#
# [10 rows x 7 columns]

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4', 'sentiment'], dtype='object')

# %%
df = data1.rename({'Unnamed: 0':'index', '0':'insta', '1':'date', '2':'like', '3':'loca', '4':'has'}, axis='columns')
df
# Out:
#       index  ... sentiment
# 0         0  ...  0.997493
# 1         1  ...  0.969207
# 2         2  ...  0.198648
# 3         3  ...  0.953208
# 4         4  ...  0.991202
# ...     ...  ...       ...
# 2346     58  ...  0.954419
# 2347     59  ...  0.955673
# 2348     60  ...  0.646488
# 2349     61  ...  0.646488
# 2350     62  ...  0.101581
#
# [2351 rows x 7 columns]

# %%
df.describe()
# Out:
#              index    sentiment
# count  2351.000000  2351.000000
# mean    435.022969     0.758283
# std     324.523069     0.330714
# min       0.000000     0.001770
# 25%     154.000000     0.615831
# 50%     381.000000     0.949241
# 75%     675.000000     0.990665
# max    1169.000000     0.998366

# %%
df.dtypes
# Out:
# index          int64
# insta         object
# date          object
# like          object
# loca          object
# has           object
# sentiment    float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# index                 int64
# insta                object
# date         datetime64[ns]
# like                 object
# loca                 object
# has                  object
# sentiment           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'insta', 'date', 'like', 'loca', 'has', 'sentiment'], dtype='object')

# %%
df['sentiment']
# Out:
# 0       0.997493
# 1       0.969207
# 2       0.198648
# 3       0.953208
# 4       0.991202
#           ...
# 2346    0.954419
# 2347    0.955673
# 2348    0.646488
# 2349    0.646488
# 2350    0.101581
# Name: sentiment, Length: 2351, dtype: float64

# %%
# df.astype({'sentiment':'float'}).dtypes
# df['sentiment'] = df['sentiment'].astype(float)
# df['sentiment'] = pd.to_numeric(df['sentiment'], errors='coerce')

# # for i in range(len(df['pn'])):
# #     if df['pn'][i] == 0:
# #         data_neg = df
# #     else:
# #         data_pos = df


# for i in range(len(df['index'])):
#     df['sentiment'][i] = df.at[df['index'][i], 'sentiment']

# %%
df['sentiment']
# Out:
# 0       0.997493
# 1       0.969207
# 2       0.198648
# 3       0.953208
# 4       0.991202
#           ...
# 2346    0.954419
# 2347    0.955673
# 2348    0.646488
# 2349    0.646488
# 2350    0.101581
# Name: sentiment, Length: 2351, dtype: float64

# %%
df['sentiment'].dtypes
# Out:
# dtype('float64')

# %%
# pip install -U imbalanced-learn

df.sort_values(['date'], ascending=True)
# Out:
#       index  ... sentiment
# 2259    768  ...  0.993543
# 2350     62  ...  0.101581
# 2349     61  ...  0.646488
# 2348     60  ...  0.646488
# 2258    767  ...  0.997689
# ...     ...  ...       ...
# 11       11  ...  0.975379
# 330       9  ...  0.518329
# 10       10  ...  0.002111
# 9         9  ...  0.996662
# 1500      9  ...  0.929252
#
# [2351 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# from imblearn.over_sampling import SMOTE

# sm = SMOTE(ratio='auto', kind='regular')

# %%
# df['sentiment'][0]

# %%
df['pn'] = 0
for i in range(len(df['sentiment'])):
  if df['sentiment'][i] > 0.5:
    df['pn'] = 1
  else:
    df['pn'] = 0

# %%
df
# Out:
#       index                                              insta  ... sentiment pn
# 0         0  #을지로 #대련집 칼국수 보쌈 둘다 맛있었다 🥳 칼국수는 약간 짭짤한 소고기국시 스...  ...  0.997493  0
# 1         1  20200703 종각 대련집신선한 알배추에 기름좔좔 수육 올리고시원한 무생채와 김치...  ...  0.969207  0
# 2         2  20/05/26/화#저녁밥#술스타그램#종로구#관ᄉ...  ...  0.198648  0
# 3         3  20/07/10/금#점심밥#혼밥#종로구#관수동...  ...  0.953208  0
# 4         4  #대련집 🐷야들야들한 #보쌈 도 맛있고묘하게 스프맛이 나던 #칼국수 도 좋네 🤭정신...  ...  0.991202  0
# ...     ...                                                ...  ...       ... ..
# 2346     58  수업 듣다 졸려서 그냥 학원에서 운영하는 카페에서 사 마셨는뎈ㅋㅋㅋㅋ 기대 안 했는...  ...  0.954419  0
# 2347     59             #파고다강남 #카페허 #cafehuh 이곳이 바로 혜자카페인가 huh  ...  0.955673  0
# 2348     60  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  0.646488  0
# 2349     61  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  0.646488  0
# 2350     62  #파고다 #C004 #파고다캘리 #파고다그램 #캘리그라피프로젝트#힘을내요슈퍼파월 #...  ...  0.101581  0
#
# ...

# %%
plt.style.use('seaborn')
plt.title("insta sentiment")
plt.plot(df['date'], df['sentiment'])
plt.show()


# from imblearn.over_sampling import SMOTE
# smote = SMOTE(k_neighbors=5, random_state=2019)

# smoted_data, smoted_label = smote.fit_resample(data, label)

# %%
# plt.figure(figsize=(100, 100)) #옆으로 늘리기
plt.plot(df['date'], df['sentiment'], 'o')

plt.show()

# %%
j=[1,2]
for i in range(len(j)):   
    positive = df['sentiment']
    negative = 1 - df['sentiment']

    test = ((positive - negative)/(positive + negative))*(positive-negative)
    for i in range(len(df['sentiment'])):
      if df['sentiment'][i] > 0.5:
        df['pn'] = 1
      else:
        df['pn'] = 0

    for i in range(len(df['sentiment'])):
        df['sentiment'][i] = test[i]

plt.plot(df['date'], df['sentiment'], 'o')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
sns.pairplot(df, vars=['date', 'sentiment'])
plt.show()

# %%
# from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE

from pandas import Series, DataFrame

data_pos = DataFrame()
data_neg = DataFrame()



# df_sent = df['sentiment'] #y value
# df_date = df['date'] #x value





# for i in range(len(df['pn'])):
#     if df['pn'][i] == 0:
#         data_neg = df
#     else:
#         data_pos = df

# sm = SMOTE(random_state=4) #ratio = 1.0

# x_SMOTE, y_SMOTE = sm.fit_sample(data_neg, df_pos) 
# print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', data_neg, data_pos)
# print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', x_SMOTE.shape, y_SMOTE.shape)
# print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_SMOTE).value_counts())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def a(x):
  if x>0.5:
    return 1
  else:
    return 0

# %%
df['np'] = df['sentiment'].apply(a)

# %%
x = df['sentiment']
y = df['np']

# %%
x = np.array(x)
x.reshape(-1,1)
x = pd.DataFrame(x)

# %%
x.shape, y.shape
# Out:
# ((2351, 1), (2351,))

# %%
from sklearn.model_selection import train_test_split
sm = SMOTE(random_state=4) #ratio = 1.0
#X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10)
x_SMOTE, y_SMOTE = sm.fit_sample(x, y) 

# print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', df[], data_pos)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', x_SMOTE.shape, y_SMOTE.shape)
print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_SMOTE).value_counts())

plt.plot(x_SMOTE, 'o')
# Out:
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트:  (2878, 1) (2878,)
# SMOTE 적용 후 레이블 값 분포:
#  1    1439
# 0    1439
# dtype: int64
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
df
# Out:
#       index                                              insta  ... sentiment np
# 0         0  #을지로 #대련집 칼국수 보쌈 둘다 맛있었다 🥳 칼국수는 약간 짭짤한 소고기국시 스...  ...  0.960387  1
# 1         1  20200703 종각 대련집신선한 알배추에 기름좔좔 수육 올리고시원한 무생채와 김치...  ...  0.579494  1
# 2         2  20/05/26/화#저녁밥#술스타그램#종로구#관ᄉ...  ...  0.074801  0
# 3         3  20/07/10/금#점심밥#혼밥#종로구#관수동...  ...  0.413679  0
# 4         4  #대련집 🐷야들야들한 #보쌈 도 맛있고묘하게 스프맛이 나던 #칼국수 도 좋네 🤭정신...  ...  0.865343  1
# ...     ...                                                ...  ...       ... ..
# 2346     58  수업 듣다 졸려서 그냥 학원에서 운영하는 카페에서 사 마셨는뎈ㅋㅋㅋㅋ 기대 안 했는...  ...  0.425070  0
# 2347     59             #파고다강남 #카페허 #cafehuh 이곳이 바로 혜자카페인가 huh  ...  0.437054  0
# 2348     60  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  0.686131  1
# 2349     61  #파고다 #C006 #파고다그램 #한강맨션 #고양이바자회 #냥스타그램 #캣스타그램#...  ...  0.686131  1
# 2350     62  #파고다 #C004 #파고다캘리 #파고다그램 #캘리그라피프로젝트#힘을내요슈퍼파월 #...  ...  0.072846  0
#
# ...

# %% [markdown]
# # **csv 형식으로 저장하기_편집된 데이터프레임**

# %%
import pandas as pd
import os

# .to_csv 
# 최초 생성 이후 mode는 append
if not os.path.exists('output.csv'):
    df.to_csv('output_eulji.csv', index=False, mode='w', encoding='utf-8-sig')
else:
    df.to_csv('output_eulji.csv', index=False, mode='a', encoding='utf-8-sig', header=False)
