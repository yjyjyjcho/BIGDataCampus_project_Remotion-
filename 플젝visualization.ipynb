# %%
import pandas as pd
import numpy as np

# raw_d = pd.read_csv('rawdata.csv')
cont_d = pd.read_csv('df_contents.csv') 
rat_sent = pd.read_csv('df_ratings_senti.csv')
rat_np = pd.read_csv('df_ratings_NumPost.csv')
# movies = pd.read_csv('movies.csv')
# ratings = pd.read_csv('ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8d9467c5bd6e> in <module>()
#       5 cont_d = pd.read_csv('df_contents.csv')
#       6 rat_sent = pd.read_csv('df_ratings_senti.csv')
# ----> 7 rat_np = pd.read_csv('df_ratings_NumPost.csv')
#       8 # movies = pd.read_csv('movies.csv')
#       9 # ratings = pd.read_csv('ratings.csv')
#
# ...

# %%
raw_d
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...     angry surprised
# 0              0             0  ...  0.934703  0.002363
# 1              1             1  ...  0.003378  0.005267
# 2              2             2  ...  0.000710  0.002507
# 3              3             3  ...  0.002136  0.006076
# 4              4             4  ...  0.005494  0.004631
# ...          ...           ...  ...       ...       ...
# 6388        6388          6388  ...  0.000902  0.000385
# 6389        6389          6389  ...  0.019135  0.006592
# 6390        6390          6390  ...  0.233722  0.002717
# 6391        6391          6391  ...  0.001900  0.001299
# 6392        6392          6392  ...       NaN       NaN
#
# [6393 rows x 19 columns]

# %% [markdown]
# ## **한글 글꼴 설정**

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
####colab용 글꼴 설치 #####
# !apt install fonts-nanum

# %%
# 일단 import 
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도


# print(mpl.__version__)
# print(mpl.__file__)
# print(mpl.get_configdir())
# print(mpl.get_cachedir())

sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
# 체크해보면 폰트 개수가 늘어났다
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
print('\n')

# 한번 프린트 해보자
nanum_font

# %%
# !python --version
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothicLight.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

# %%
# 그래프를 그려보자. 하지만 한글은 깨진다

# 데이터 준비
import numpy as np

data = np.random.randint(-200, 100, 50).cumsum()
data

plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('seaborn-pastel')
plt.show()

# %%
# 우선 fm._rebuild() 를 해주고
fm._rebuild()

# %%
for font in font_manager.fontManager.ttflist:
    if 'Nanum' in font.name:
        print(font.name, font.fname)

plt.rc('font', family='NanumMyeongjo')
plt.text(0.3, 0.3, '한글', size=100)

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
font_list[:5]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
# plt.rc('font', family='NanumSquareRoundR')
rc('font', family='NanumGothic')

# %%
a = fm.FontProperties(fname=font_list[0])
a.get_name()

# %%
raw_df = raw_d[['Unnamed: 0', 'date', 'like', 'loca', 'sentiment', 'happy', 'sad', 'angry', 'surprised']]
raw_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d57f44f6a03> in <module>()
# ----> 1 raw_df = raw_d[['Unnamed: 0', 'date', 'like', 'loca', 'sentiment', 'happy', 'sad', 'angry', 'surprised']]
#       2 raw_df
#
# NameError: name 'raw_d' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
##한글 글꼴 설정##
# plt.rc('font', family='Malgun Gothic')

# sns.pairplot(raw_d, hue="loca", markers=["o", "s", "D"])
# plt.show()

raw_df = raw_d[['Unnamed: 0', 'date', 'like', 'loca', 'sentiment', 'happy', 'sad', 'angry', 'surprised']]


sns.countplot(x="loca", data=raw_df)
plt.rcParams["figure.figsize"] = (30, 9)
plt.show()
